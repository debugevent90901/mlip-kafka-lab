# %% [markdown]
# # Kafka Demo
#
# ### Connect to Kafka Broker Server
# ```
# ssh -o ServerAliveInterval=60 -L 9092:localhost:9092 tunnel@128.2.204.215 -NTf
# ```
# pass: seaitunnel
#
#
# To kill connection at port:
# ```
# lsof -ti:9092 | xargs kill -9
# ```
#
# ### Setup
# ```
# python -m pip install kafka-python
# ```

# %%
from os import path
import sys, os
from datetime import datetime
from json import dumps, loads
from time import sleep
from random import randint
import numpy as np
# ssh -o ServerAliveInterval=60 -L 9092:localhost:9092 tunnel@128.2.24.106 -NTf
from kafka import KafkaConsumer, KafkaProducer

# Update this for your own recitation section :)
topic = 'recitation-f'

# %% [markdown]
# ### Producer Mode -> Writes Data to Broker

# %%
# Create a producer to write data to kafka
# Ref: https://kafka-python.readthedocs.io/en/master/apidoc/KafkaProducer.html

# [TODO]: Replace '...' with the address of your Kafka bootstrap server
producer = KafkaProducer(bootstrap_servers=['localhost:9092'],
                        value_serializer=lambda x: dumps(x).encode('utf-8'),
                        )

# [TODO]: Add cities of your choice
cities = ['Warsaw', 'Berlin', 'Prague', 'Vienna', 'Budapest', 'Belgrade', 'Bucharest', 'Sofia']

# Write data via the producer
print("Writing to Kafka Broker")
for i in range(10):
    data = f'{datetime.now().strftime("%Y-%m-%d %H:%M:%S")},{cities[randint(0,len(cities)-1)]},{randint(18, 32)}ºC'
    print(f"Writing: {data}")
    producer.send(topic=topic, value=data)
    sleep(1)
# Out:
# Writing to Kafka Broker
# Writing: 2024-01-26 14:13:16,Warsaw,27ºC
# Writing: 2024-01-26 14:13:17,Belgrade,18ºC
# Writing: 2024-01-26 14:13:18,Budapest,30ºC
# Writing: 2024-01-26 14:13:19,Sofia,22ºC
# Writing: 2024-01-26 14:13:20,Berlin,30ºC
# Writing: 2024-01-26 14:13:21,Budapest,31ºC
# Writing: 2024-01-26 14:13:22,Belgrade,23ºC
# Writing: 2024-01-26 14:13:23,Bucharest,28ºC
# Writing: 2024-01-26 14:13:24,Belgrade,32ºC
# Writing: 2024-01-26 14:13:25,Prague,21ºC

# %% [markdown]
# ### Consumer Mode -> Reads Data from Broker

# %%
# Create a consumer to read data from kafka
# Ref: https://kafka-python.readthedocs.io/en/master/apidoc/KafkaConsumer.html

# [TODO]: Complete the missing ... parameters/arguments using the Kafka documentation
consumer = KafkaConsumer(
    topic,
    bootstrap_servers=['localhost:9092'],
    auto_offset_reset='earliest', #Experiment with different values
    # Commit that an offset has been read
    enable_auto_commit=True,
    # How often to tell Kafka, an offset has been read
    auto_commit_interval_ms=1000
)

print('Reading Kafka Broker')
for message in consumer:

    message = message.value.decode()
    # Default message.value type is bytes!
    print(loads(message))
    os.system(f"echo {message} >> kafka_log.csv")
# Out:
# Reading Kafka Broker
# 2024-01-25 14:50:09,San Diego,18ºC
# 2024-01-25 14:50:11,Irvine,23ºC
# 2024-01-26 14:11:07,Chicago,20ºC
# 2024-01-26 14:11:09,Mumbai,30ºC
# 2024-01-26 14:11:08,New York City,30ºC
# 2024-01-26 14:11:09,New York City,28ºC
# 2024-01-26 14:11:10,New York City,22ºC
# 2024-01-26 14:11:11,Chicago,24ºC
# 2024-01-26 14:11:12,Chicago,27ºC
# 2024-01-26 14:11:13,New York City,28ºC
# 2024-01-26 14:11:14,New York City,26ºC
# 2024-01-26 14:11:15,New York City,32ºC
# 2024-01-26 14:12:24,Pittsburgh,31ºC
# 2024-01-26 14:12:25,Philadelphia,18ºC
# 2024-01-26 14:12:26,Pittsburgh,18ºC
# 2024-01-26 14:12:27,New York City,24ºC
# 2024-01-26 14:12:28,Pittsburgh,26ºC
# 2024-01-26 14:12:29,Pittsburgh,26ºC
# 2024-01-26 14:12:30,New York City,25ºC
# 2024-01-26 14:12:31,Philadelphia,30ºC
# 2024-01-26 14:12:32,New York City,19ºC
# 2024-01-26 14:12:33,Pittsburgh,27ºC
# 2024-01-26 14:12:52,Prague,28ºC
# 2024-01-26 14:12:53,Belgrade,22ºC
# 2024-01-26 14:12:54,Prague,22ºC
# 2024-01-26 14:12:55,Sofia,29ºC
# 2024-01-26 14:12:56,Sofia,21ºC
# 2024-01-26 14:12:57,Vienna,30ºC
# 2024-01-26 14:12:58,Belgrade,31ºC
# 2024-01-26 14:12:59,Warsaw,24ºC
# 2024-01-26 14:13:00,Budapest,21ºC
# 2024-01-26 14:13:01,Budapest,18ºC
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 16
#       5 consumer = KafkaConsumer(
#       6     topic,
#       7     bootstrap_servers=['localhost:9092'],
#    (...)
#      12     auto_commit_interval_ms=1000
#      13 )
#      15 print('Reading Kafka Broker')
# ---> 16 for message in consumer:
#      18     message = message.value.decode()
#      19     # Default message.value type is bytes!
#
# File /usr/local/lib/python3.11/site-packages/kafka/consumer/group.py:1193, in KafkaConsumer.__next__(self)
#    1191     return self.next_v1()
#    1192 else:
# -> 1193     return self.next_v2()
#
# File /usr/local/lib/python3.11/site-packages/kafka/consumer/group.py:1201, in KafkaConsumer.next_v2(self)
#    1199     self._iterator = self._message_generator_v2()
#    1200 try:
# -> 1201     return next(self._iterator)
#    1202 except StopIteration:
#    1203     self._iterator = None
#
# File /usr/local/lib/python3.11/site-packages/kafka/consumer/group.py:1116, in KafkaConsumer._message_generator_v2(self)
#    1114 def _message_generator_v2(self):
#    1115     timeout_ms = 1000 * (self._consumer_timeout - time.time())
# -> 1116     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1117     for tp, records in six.iteritems(record_map):
#    1118         # Generators are stateful, and it is possible that the tp / records
#    1119         # here may become stale during iteration -- i.e., we seek to a
#    1120         # different offset, pause consumption, or lose assignment.
#    1121         for record in records:
#    1122             # is_fetchable(tp) should handle assignment changes and offset
#    1123             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1124             # outer function destroying the existing iterator/generator
#    1125             # via self._iterator = None
#
# File /usr/local/lib/python3.11/site-packages/kafka/consumer/group.py:655, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     653 remaining = timeout_ms
#     654 while True:
# --> 655     records = self._poll_once(remaining, max_records, update_offsets=update_offsets)
#     656     if records:
#     657         return records
#
# File /usr/local/lib/python3.11/site-packages/kafka/consumer/group.py:702, in KafkaConsumer._poll_once(self, timeout_ms, max_records, update_offsets)
#     699     self._client.poll(timeout_ms=0)
#     701 timeout_ms = min(timeout_ms, self._coordinator.time_to_next_poll() * 1000)
# --> 702 self._client.poll(timeout_ms=timeout_ms)
#     703 # after the long poll, we should check whether the group needs to rebalance
#     704 # prior to returning data so that the group can stabilize faster
#     705 if self._coordinator.need_rejoin():
#
# File /usr/local/lib/python3.11/site-packages/kafka/client_async.py:602, in KafkaClient.poll(self, timeout_ms, future)
#     599             timeout = min(timeout, self.config['retry_backoff_ms'])
#     600         timeout = max(0, timeout)  # avoid negative timeouts
# --> 602     self._poll(timeout / 1000)
#     604 # called without the lock to avoid deadlock potential
#     605 # if handlers need to acquire locks
#     606 responses.extend(self._fire_pending_completed_requests())
#
# File /usr/local/lib/python3.11/site-packages/kafka/client_async.py:634, in KafkaClient._poll(self, timeout)
#     631 self._register_send_sockets()
#     633 start_select = time.time()
# --> 634 ready = self._selector.select(timeout)
#     635 end_select = time.time()
#     636 if self._sensors:
#
# File /usr/local/Cellar/python@3.11/3.11.6_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/selectors.py:566, in KqueueSelector.select(self, timeout)
#     564 ready = []
#     565 try:
# --> 566     kev_list = self._selector.control(None, max_ev, timeout)
#     567 except InterruptedError:
#     568     return ready
#
# KeyboardInterrupt:

# %% [markdown]
# # Use kcat!
# It's a CLI (Command Line Interface). Previously known as kafkacat
#
#
# Ref: https://docs.confluent.io/platform/current/app-development/kafkacat-usage.html

# %%
#kcat command: connect to local Kafka broker, specify a topic, and consume messages from the earliest offset
